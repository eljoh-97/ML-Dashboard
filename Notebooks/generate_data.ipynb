# %% [markdown]
# Create the datasets with Faker

# %%
from faker import Faker
import random
import numpy as np
import uuid
import pandas as pd
from datetime import date, datetime

# %%
# datasets:
# 1. Customer-list // Support-set
# 2. Contact-list // Support-set
# 3. CRM-data, customer interaction (meetings etc.)
# 4. Offer-data / Sales-data


fake = Faker()

# %% [markdown]
# Create a function for the first dataset "Customer-list"

# %%
# 1. Customer-list
def create_customer(x): 
    industry = ['Automobile Manufacturers (OEMs)', 'Automotive R&D and Testing Centers',
                'Electric Vehicle (EV) Industry', 'Ridesharing & Mobility Services', 
                'Connected Car Solutions Providers', 'Fleet Management']
    size = ['Small', 'Medium', 'Large']
    
    # Generate unique company IDs
    unique_ids = random.sample(range(1, x * 10), x)  # Ensure enough range to avoid collisions
    
    customer = {}
    for i, company_id in enumerate(unique_ids):
        customer[i] = {}
        customer[i]['companyId'] = company_id
        customer[i]['company'] = fake.company()
        customer[i]['size'] = fake.random_element(size)
        customer[i]['industry'] = fake.random_element(industry)
        customer[i]['city'] = fake.city()
        customer[i]['state'] = fake.state()
        customer[i]['zipcode'] = fake.postcode()
    
    return customer

# %% [markdown]
# Create a function for the second dataset "Contact-list"

# %%
def create_contacts(customers, num_contacts):
    roles = ['Sales Manager', 'Technical Manager', 'Sales Representative', 
             'Technical Representative', 'CEO', 'CCO', 'CFO']
    
    contacts = []
    existing_contact_ids = set()  # Keep track of existing contact IDs to avoid duplicates
    
    for company in customers.values():
        contact = {
            'companyId': company['companyId'],
            'company': company['company'],
            'contactId': str(uuid.uuid4()),  # Unique contactId using UUID
            'first_name': fake.first_name(),
            'last_name': fake.last_name(),
            'roles': random.choice(roles),
            'contactPerson': f"{fake.first_name()} {fake.last_name()}",
            'email': f"{fake.first_name().lower()}.{fake.last_name().lower()}@{company['company'].lower().replace(' ', '')}.com",
            'phone_number': fake.phone_number()
        }
        
        # Ensure no duplicate contact ID
        while contact['contactId'] in existing_contact_ids:
            contact['contactId'] = str(uuid.uuid4())
        
        existing_contact_ids.add(contact['contactId'])
        contacts.append(contact)
    
    # Add more random contacts if needed
    while len(contacts) < num_contacts:
        customer = random.choice(list(customers.values()))
        contact = {
            'companyId': customer['companyId'],
            'company': customer['company'],
            'contactId': str(uuid.uuid4()),  # Unique contactId using UUID
            'first_name': fake.first_name(),
            'last_name': fake.last_name(),
            'roles': random.choice(roles),
            'contactPerson': f"{fake.first_name()} {fake.last_name()}",
            'email': f"{fake.first_name().lower()}.{fake.last_name().lower()}@{customer['company'].lower().replace(' ', '')}.com",
            'phone_number': fake.phone_number()
        }
        
        # Ensure no duplicate contact ID
        while contact['contactId'] in existing_contact_ids:
            contact['contactId'] = str(uuid.uuid4())
        
        existing_contact_ids.add(contact['contactId'])
        contacts.append(contact)
    
    return contacts

# %% [markdown]
# Create a function for the third dataset, "CRM-data"

# %%
def create_crm_interaction(customers, contacts, num_interactions):

    # Define possible interaction types and subjects
    interaction_types = ['Digital meeting', 'Physical meeting', 'Email', 'Phone Call']
    interaction_subjects = [
        'Discuss project details',
        'Follow-up on order',
        'Follow-up on proposal',
        'Customer inquiry',
        'Contract negotiation',
        'Product feedback',
        'Product demostration'
    ]
    
    start_date = date(2021,10,30)
    end_date = date(2024,10,30)
    

    # Generate random CRM interactions
    interactions = []
    for _ in range(num_interactions):  # Generate based on num_interactions
        interaction = {}

        # Randomly select a customer
        customer = random.choice(list(customers.values()))
        companyId = customer['companyId']

        # Filter contacts for the selected company
        company_contacts = [c for c in contacts if c['companyId'] == companyId]
        if not company_contacts:  # Skip if no contacts exist for this company
            continue

        # Randomly select a contact from the company contacts
        contact = random.choice(company_contacts)
        
        interaction['company'] = customer['company']
        interaction['companyId'] = customer['companyId']
        interaction['contactId'] = contact['contactId']
        interaction['contactPerson'] = f"{contact['first_name']} {contact['last_name']}"
        interaction['interactionType'] = random.choice(interaction_types)
        interaction['interactionSubject'] = random.choice(interaction_subjects)
        interaction['interactionDate'] = fake.date_between_dates(start_date, end_date)

        interactions.append(interaction)

    return interactions

# %% [markdown]
# Create a function for the fourth dataset "Sales-data"

# %%
# 4. Sales-data    
def create_sales_data(customers, contacts, num_offers):
    offers = []
    for _ in range(num_offers):
        offer = {}
        offer_status = ['Open', 'Closed']
        offer_rate = [0.55, 0.45]
        start_date = date(2021,10,30)
        end_date = date(2024,10,30)
    
        
        # Randomly select a customer
        customer = random.choice(list(customers.values()))
        companyId = customer['companyId']

        # Filter contacts for the selected company
        company_contacts = [c for c in contacts if c['companyId'] == companyId]
        if not company_contacts:  # Skip if no contacts exist for this company
            continue

        # Randomly select a contact from the company contacts
        contact = random.choice(company_contacts)
        
        offer['offerNo'] = random.randint(1, 5000)
        offer['company'] = customer['company']
        offer['companyId'] = customer['companyId']
        offer['contactId'] = contact['contactId']
        offer['contactPerson'] = f"{contact['first_name']} {contact['last_name']}"
        offer['offerValue'] = round(np.random.normal(10000,1000),2)
        offer['offerDate'] = fake.date_between_dates(start_date, end_date)
        offer['offerStatus'] = np.random.choice(offer_status, p=offer_rate)
        
        offers.append(offer)
        

    return offers

# %% [markdown]
# Apply the functions, and create the datasets

# %%
customers = create_customer(2000) # How many customers
contacts = create_contacts(customers, 4000) # How many contacts
interaction = create_crm_interaction(customers, contacts, 32000) # How many interactions
offer = create_sales_data(customers, contacts, 40000) # How many offers

df_customers = pd.DataFrame(customers).transpose() 
df_contacts = pd.DataFrame(contacts)
df_interaction = pd.DataFrame(interaction)
df_offer = pd.DataFrame(offer)

# %% [markdown]
# Check for duplicates in customer and contacts dfs

# %%
print(f"Duplicate companyId in df_customers: {df_customers['companyId'].duplicated().sum()}")
print(f"Duplicate contactId in df_contacts: {df_contacts['contactId'].duplicated().sum()}")
# Out:
# Duplicate companyId in df_customers: 0
# Duplicate contactId in df_contacts: 0

# %% [markdown]
# Check the created dataframes

# %%
df_customers
# Out:
#      companyId                       company    size  \
# 0         7888      Ramirez, Miller and Reed  Medium
# 1         6486                Evans-Thompson  Medium
# 2        15559                   Collins LLC   Small
# 3         6004     Lam, Bailey and Fernandez   Large
# 4         2488                    Martin Inc  Medium
# ...        ...                           ...     ...
# 1995      5156                     Jones PLC   Large
# 1996     10656      Becker, Lewis and Zamora   Small
# 1997      3974                    Love-Jones   Small
# 1998     18778  Murphy, Jordan and Velasquez   Large
# 1999     12806   Perez, Rodriguez and Medina   Small
#
#                                 industry            city           state  \
# 0         Electric Vehicle (EV) Industry     Jeffreybury        Virginia
# 1        Automobile Manufacturers (OEMs)     Lake Jeanne    Pennsylvania
# 2      Connected Car Solutions Providers    New Amyshire     Connecticut
# 3     Automotive R&D and Testing Centers      Robertside        New York
# 4      Connected Car Solutions Providers     Freemanbury  North Carolina
# ...                                  ...             ...             ...
# 1995   Connected Car Solutions Providers       Sawyerton      California
# 1996      Electric Vehicle (EV) Industry     North Caleb        Kentucky
# 1997      Electric Vehicle (EV) Industry        Bondtown        New York
# 1998     Ridesharing & Mobility Services  North Kellyton    North Dakota
# 1999  Automotive R&D and Testing Centers        Rossbury    North Dakota
#
#      zipcode
# 0      87273
# 1      02208
# 2      78135
# 3      53513
# 4      63715
# ...      ...
# 1995   81922
# 1996   66423
# 1997   61923
# 1998   97406
# 1999   60894
#
# [2000 rows x 7 columns]

# %%
df_contacts
# Out:
#       companyId                    company  \
# 0          7888   Ramirez, Miller and Reed
# 1          6486             Evans-Thompson
# 2         15559                Collins LLC
# 3          6004  Lam, Bailey and Fernandez
# 4          2488                 Martin Inc
# ...         ...                        ...
# 3995        624  Brown, White and Martinez
# 3996       7308    Jones, Hardy and Harvey
# 3997       5111                  Brown Ltd
# 3998       1023                 Tanner LLC
# 3999       1357               Evans-Graves
#
#                                  contactId first_name last_name  \
# 0     7a2cf7e2-1c73-4b78-8b66-b951d251abc8    Tiffany      Wang
# 1     e835c78a-32b1-4a0e-b7e0-b98d27a3a732      Karen   Sanders
# 2     1db8096d-0909-4917-bd29-4998b6258828  Stephanie  Browning
# 3     67dcb80c-fe73-46b9-921f-fc960d3f80cd      Keith      Boyd
# 4     dcc5e209-838b-4b1e-9cf4-fd272905bc4c      Henry     Jones
# ...                                    ...        ...       ...
# 3995  60d9c228-0fdb-4bff-bbf9-13ee9cf558a1    Michael      Kent
# 3996  e8eb22df-a417-4b38-a518-e8a05e3e4395    Felicia    Bailey
# 3997  f30ff650-d761-4055-bd44-a526d117cede  Stephanie  Mckinney
# 3998  404768a5-3aa5-46de-a020-0ec418f784a3    Antonio    Curtis
# 3999  bc3e9044-0538-49b9-8b7f-25536b5aa91a     Joseph    Norton
#
#                          roles       contactPerson  \
# 0         Sales Representative        Jodi Stewart
# 1                Sales Manager       Jeremy Martin
# 2                          CFO        Omar Meadows
# 3         Sales Representative          Luke Smith
# 4         Sales Representative         Todd Sawyer
# ...                        ...                 ...
# 3995      Sales Representative         Devon Dixon
# 3996  Technical Representative  Richard Richardson
# 3997                       CCO            Jake Lee
# 3998         Technical Manager      Sandra Aguilar
# 3999                       CEO          Noah Rocha
#
#                                          email          phone_number
# 0      jessica.brown@ramirez,millerandreed.com          464.440.9455
# 1            michael.pruitt@evans-thompson.com      001-840-696-3710
# 2                 michael.brown@collinsllc.com  +1-920-262-6802x8872
# 3      maria.duncan@lam,baileyandfernandez.com  +1-782-698-3575x8878
# 4              victoria.morrison@martininc.com         (383)732-8018
# ...                                        ...                   ...
# 3995  melissa.grant@brown,whiteandmartinez.com   (710)916-2355x49499
# 3996  lindsay.jackson@jones,hardyandharvey.com  +1-306-882-9026x5605
# 3997                 mark.sweeney@brownltd.com      822-413-1220x788
# 3998            jennifer.collins@tannerllc.com            6498790550
# 3999       jennifer.rodriguez@evans-graves.com         (796)732-8195
#
# [4000 rows x 9 columns]

# %%
df_interaction
# Out:
#                         company  companyId  \
# 0                  Walker Group      19882
# 1                 Henderson Inc      11700
# 2        Allen, Taylor and Kerr      12932
# 3      Johnson, Cross and Henry      18281
# 4                    Bailey LLC       9514
# ...                         ...        ...
# 31995              Walters-Reid       2628
# 31996                Walker Ltd      17622
# 31997             Meadows Group      15558
# 31998           Huffman-Jackson       5029
# 31999                Murphy PLC        507
#
#                                   contactId    contactPerson  \
# 0      bf67622d-e30a-487b-8916-e2948450f101      Shawn Green
# 1      4e087457-362d-4cf4-a78b-32cadc6aeccc    Jacob Estrada
# 2      2f85292f-ce28-42d7-89bd-10f13b30f0da       Lee Bryant
# 3      99ecb82d-8463-4f4a-8bd1-0b182c8afd3c    Cody Griffith
# 4      0c390f89-2c22-44ee-8f6d-7c2217d66346      Derek Woods
# ...                                     ...              ...
# 31995  ebaa0d5d-85b2-4510-9c64-ef3dbdf44971   Shelly Coleman
# 31996  0c00e416-d0de-43fb-8bae-db7c0af0a72a  Alison Williams
# 31997  aff2c1e9-e532-4f7d-9f0e-d879d411fa21   Theodore White
# 31998  3f04f05f-001f-4b3f-bea6-285d9c2fc077    Rachel Barnes
# 31999  422da60c-0da5-48ad-a0a0-1d61e37bac25     Renee Bowman
#
#         interactionType       interactionSubject interactionDate
# 0       Digital meeting         Product feedback      2021-11-06
# 1            Phone Call  Discuss project details      2022-02-02
# 2                 Email     Contract negotiation      2022-05-25
# 3      Physical meeting     Contract negotiation      2022-07-27
# 4      Physical meeting     Contract negotiation      2022-11-22
# ...                 ...                      ...             ...
# 31995             Email         Product feedback      2024-02-17
# 31996             Email         Customer inquiry      2024-05-29
# 31997  Physical meeting         Customer inquiry      2023-05-12
# 31998  Physical meeting     Contract negotiation      2023-07-21
# 31999  Physical meeting       Follow-up on order      2022-05-19
#
# [32000 rows x 7 columns]

# %%
df_offer
# Out:
#        offerNo                      company  companyId  \
# 0         4883           Alexander and Sons      13351
# 1         3459              Fuller and Sons      18486
# 2         2856                   Obrien Inc        592
# 3         3850              Williams-Garcia      13887
# 4         1035                   Bryant LLC       4896
# ...        ...                          ...        ...
# 39995     1515  Nelson, Harrison and Miller       7526
# 39996      821    Scott, Smith and Thompson       2910
# 39997     2617              Oconnor-Acevedo       7933
# 39998     3279              Potter and Sons        864
# 39999     1005    Walker, Walker and Larson       5750
#
#                                   contactId      contactPerson  offerValue  \
# 0      4f837552-42d0-4a60-b6db-9e1e9002c6b0      Kristine Rose    12497.74
# 1      0f01c50f-542c-4849-8d75-1bf43c08a739   Stephen Calderon    10736.43
# 2      90dad980-7a87-450b-9408-4dc81041dccd       Sherry Ellis     9566.43
# 3      ed2ab6a1-eeb0-4ab6-94fc-253fd4f9c69c        Tammy Singh    10655.95
# 4      61d95f82-9c67-41c9-a879-9e3ce950ebf4     Debra Anderson     9584.21
# ...                                     ...                ...         ...
# 39995  f38816c6-515a-4adc-9e21-683d7b7bf08f         Jesse Bond    10726.05
# 39996  58e1f45f-97ca-43fd-9089-00a05ef07104  Christopher Grant    10666.87
# 39997  4c540cf4-5851-4c3d-9f4e-2494f7728c61    Nicole Mitchell    10913.83
# 39998  f3e50efe-371e-4ab6-869c-ccb3c68ec570         Emily Bell     8837.48
# 39999  a9b2502d-c94f-4116-9f06-14913d80845d         Carl Horne    10330.62
#
#         offerDate offerStatus
# 0      2024-01-08        Open
# 1      2024-07-01      Closed
# 2      2022-01-04        Open
# 3      2022-03-31      Closed
# 4      2021-12-18        Open
# ...           ...         ...
# 39995  2021-11-01        Open
# 39996  2022-07-21        Open
# 39997  2023-02-26        Open
# 39998  2022-08-19      Closed
# 39999  2022-08-14      Closed
#
# [40000 rows x 8 columns]

# %% [markdown]
# Merge customers with contacts

# %%
df_merge = pd.merge(df_customers, df_contacts, on=['companyId', 'company'], how='left')
df_merge
# Out:
#      companyId                       company    size  \
# 0         7888      Ramirez, Miller and Reed  Medium
# 1         7888      Ramirez, Miller and Reed  Medium
# 2         6486                Evans-Thompson  Medium
# 3         6486                Evans-Thompson  Medium
# 4         6486                Evans-Thompson  Medium
# ...        ...                           ...     ...
# 3995      3974                    Love-Jones   Small
# 3996     18778  Murphy, Jordan and Velasquez   Large
# 3997     18778  Murphy, Jordan and Velasquez   Large
# 3998     12806   Perez, Rodriguez and Medina   Small
# 3999     12806   Perez, Rodriguez and Medina   Small
#
#                                 industry            city         state  \
# 0         Electric Vehicle (EV) Industry     Jeffreybury      Virginia
# 1         Electric Vehicle (EV) Industry     Jeffreybury      Virginia
# 2        Automobile Manufacturers (OEMs)     Lake Jeanne  Pennsylvania
# 3        Automobile Manufacturers (OEMs)     Lake Jeanne  Pennsylvania
# 4        Automobile Manufacturers (OEMs)     Lake Jeanne  Pennsylvania
# ...                                  ...             ...           ...
# 3995      Electric Vehicle (EV) Industry        Bondtown      New York
# 3996     Ridesharing & Mobility Services  North Kellyton  North Dakota
# 3997     Ridesharing & Mobility Services  North Kellyton  North Dakota
# 3998  Automotive R&D and Testing Centers        Rossbury  North Dakota
# 3999  Automotive R&D and Testing Centers        Rossbury  North Dakota
#
#      zipcode                             contactId first_name  last_name  \
# 0      87273  7a2cf7e2-1c73-4b78-8b66-b951d251abc8    Tiffany       Wang
# 1      87273  1b779442-ee63-4623-a075-0312c0d84b6c      Nancy      Small
# 2      02208  e835c78a-32b1-4a0e-b7e0-b98d27a3a732      Karen    Sanders
# 3      02208  efc56df5-05b1-4d61-a3ae-3aee2c618c10     Denise       Gill
# 4      02208  65ab2e0e-8abc-4bd0-88db-922e05c4acc1     Hannah     Becker
# ...      ...                                   ...        ...        ...
# 3995   61923  29733022-0ae9-4fe5-93ac-7cbea84b23ea      Carly   Gonzalez
# 3996   97406  5c869ebc-66f1-44cd-a54b-fe66e736f363     Thomas  Mccormick
# 3997   97406  869000d7-f99f-4aee-ad1b-639da4c867f3   Samantha   Valencia
# 3998   60894  38817d95-7bf1-4623-8f43-9455a855b878    Matthew    Hoffman
# 3999   60894  9bd3bea5-b109-4529-830a-f470df833203   Jennifer      James
#
#                          roles     contactPerson  \
# 0         Sales Representative      Jodi Stewart
# 1                          CEO    Pamela Ramirez
# 2                Sales Manager     Jeremy Martin
# 3            Technical Manager  Stephanie Wilson
# 4            Technical Manager         Ian Woods
# ...                        ...               ...
# 3995             Sales Manager     Ronald Little
# 3996  Technical Representative      Eric Johnson
# 3997  Technical Representative       Sarah Ochoa
# 3998                       CFO     Amanda Mathis
# 3999                       CCO      Aaron Barton
#
#                                                 email        phone_number
# 0             jessica.brown@ramirez,millerandreed.com        464.440.9455
# 1               scott.lewis@ramirez,millerandreed.com          2265472025
# 2                   michael.pruitt@evans-thompson.com    001-840-696-3710
# 3                  george.davidson@evans-thompson.com       (562)267-0854
# 4                     chris.robles@evans-thompson.com          5869692354
# ...                                               ...                 ...
# 3995                      dennis.price@love-jones.com  (668)915-6409x9420
# 3996  elizabeth.jimenez@murphy,jordanandvelasquez.com       (829)608-4067
# 3997       nicole.allen@murphy,jordanandvelasquez.com   895-943-0184x0684
# 3998        jason.ibarra@perez,rodriguezandmedina.com       (346)895-0398
# 3999        bailey.brown@perez,rodriguezandmedina.com        666.555.3823
#
# [4000 rows x 14 columns]

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   companyId      4000 non-null   object
#  1   company        4000 non-null   object
#  2   size           4000 non-null   object
#  3   industry       4000 non-null   object
#  4   city           4000 non-null   object
#  5   state          4000 non-null   object
#  6   zipcode        4000 non-null   object
#  7   contactId      4000 non-null   object
#  8   first_name     4000 non-null   object
#  9   last_name      4000 non-null   object
#  10  roles          4000 non-null   object
#  11  contactPerson  4000 non-null   object
#  12  email          4000 non-null   object
#  13  phone_number   4000 non-null   object
# dtypes: object(14)
# memory usage: 437.6+ KB

# %% [markdown]
# Map certain of columns and agg. the data to get a better strucuted data

# %%
df_contacts2 = df_merge.groupby(['companyId', 'company', 'size', 'industry', 'city', 'state']).agg(
    contacts=('contactPerson', 'count'),
    roles=('roles', lambda x: ', '.join(x.dropna().astype(str).unique()))
).reset_index()

# %%
df_contacts2
# Out:
#       companyId                          company    size  \
# 0            13              Stephens-Washington   Large
# 1            16                        Moore Ltd   Large
# 2            23                      Payne Group   Large
# 3            31      Martinez, Benson and Bowman   Large
# 4            39                       Meyer-Gill  Medium
# ...         ...                              ...     ...
# 1995      19961                      Stanley Inc   Small
# 1996      19975                        Hayes PLC   Small
# 1997      19978           Parks, Moss and Howell   Large
# 1998      19980  Nixon, Zimmerman and Washington  Medium
# 1999      19985                        Rocha Ltd   Small
#
#                                 industry               city           state  \
# 0        Ridesharing & Mobility Services  New Yvonneborough        Delaware
# 1      Connected Car Solutions Providers          Brianstad       Tennessee
# 2        Automobile Manufacturers (OEMs)       North Sylvia           Texas
# 3                       Fleet Management          Ginamouth  North Carolina
# 4     Automotive R&D and Testing Centers         Loganville         Arizona
# ...                                  ...                ...             ...
# 1995                    Fleet Management           Donburgh         Indiana
# 1996   Connected Car Solutions Providers        Thomasmouth         Vermont
# 1997                    Fleet Management      Lake Johnview        Colorado
# 1998     Ridesharing & Mobility Services      New Jasonberg         Vermont
# 1999                    Fleet Management      West Samantha   West Virginia
#
#       contacts                                             roles
# 0            2                                Sales Manager, CEO
# 1            2                         CFO, Sales Representative
# 2            1                                     Sales Manager
# 3            2                                          CCO, CFO
# 4            4          CEO, Sales Representative, Sales Manager
# ...        ...                                               ...
# 1995         2                                Sales Manager, CFO
# 1996         4             Sales Manager, CEO, Technical Manager
# 1997         2                                     Sales Manager
# 1998         1                          Technical Representative
# 1999         4  Technical Manager, Technical Representative, CEO
#
# [2000 rows x 8 columns]

# %%
df_interactions2 = df_interaction.groupby(['company', 'companyId']).agg(
    interactions=('interactionType', 'count'),
    lastInteractionDate=('interactionDate', 'max'),
    interactionSubjects=('interactionSubject', lambda x: ', '.join(x.dropna().astype(str).unique()))
).reset_index()

# %%
df_interactions2
# Out:
#                  company  companyId  interactions lastInteractionDate  \
# 0          Acevedo Group      15380            14          2024-06-15
# 1             Acosta LLC       3381            11          2024-10-14
# 2             Acosta LLC      11049            16          2024-10-04
# 3         Acosta-Osborne       2274            20          2024-10-18
# 4              Adams PLC       1919            12          2024-09-13
# ...                  ...        ...           ...                 ...
# 1995        Young-Rangel       8510            12          2024-10-11
# 1996        Young-Walter       9988            19          2024-09-13
# 1997        Young-Wilson       2360            12          2024-09-15
# 1998              Yu Inc      18658            19          2024-08-24
# 1999  Zimmerman and Sons       3816            10          2024-08-13
#
#                                     interactionSubjects
# 0     Product demostration, Contract negotiation, Fo...
# 1     Contract negotiation, Customer inquiry, Produc...
# 2     Product feedback, Follow-up on order, Product ...
# 3     Follow-up on proposal, Follow-up on order, Dis...
# 4     Customer inquiry, Discuss project details, Pro...
# ...                                                 ...
# 1995  Customer inquiry, Contract negotiation, Discus...
# 1996  Contract negotiation, Customer inquiry, Produc...
# 1997  Customer inquiry, Product demostration, Discus...
# 1998  Follow-up on proposal, Product feedback, Produ...
# 1999  Follow-up on proposal, Follow-up on order, Con...
#
# [2000 rows x 5 columns]

# %%
df_offer2 = df_offer.groupby(['company', 'companyId']).agg(
    offers=('offerNo', 'count'),
    averageOfferValue=('offerValue', 'mean'),
    offerClosed=('offerStatus', lambda x: ((x =='Closed').sum())),
    lastOfferDate=('offerDate', 'max')
).reset_index().round(2)

# %%
df_offer2
# Out:
#                  company  companyId  offers  averageOfferValue  offerClosed  \
# 0          Acevedo Group      15380      17           10183.15            8
# 1             Acosta LLC       3381      18            9939.37           11
# 2             Acosta LLC      11049      19           10162.91            7
# 3         Acosta-Osborne       2274      13           10130.35            8
# 4              Adams PLC       1919      19           10117.22           13
# ...                  ...        ...     ...                ...          ...
# 1995        Young-Rangel       8510      27           10050.65           16
# 1996        Young-Walter       9988      17           10336.17            7
# 1997        Young-Wilson       2360      21            9941.90           11
# 1998              Yu Inc      18658      18           10194.10            5
# 1999  Zimmerman and Sons       3816      19           10150.52            8
#
#      lastOfferDate
# 0       2024-10-18
# 1       2024-09-30
# 2       2024-10-25
# 3       2024-09-25
# 4       2024-10-12
# ...            ...
# 1995    2024-09-06
# 1996    2024-07-15
# 1997    2024-07-12
# 1998    2024-07-30
# 1999    2024-07-18
#
# [2000 rows x 6 columns]

# %% [markdown]
# Create new columns/features for interaction and offer dataset.
# Based on lastInteractionDate and lastOfferDate

# %%
df_interactions2['lastInteractionDate'] = pd.to_datetime(df_interactions2['lastInteractionDate'], errors='coerce')
df_offer2['lastOfferDate'] = pd.to_datetime(df_offer2['lastOfferDate'], errors='coerce')

# %% [markdown]
# Define a date_measure

# %%
date_measure = pd.to_datetime('2024-12-01')

# %% [markdown]
# Create the first feature based on lastInteractionDate

# %%
df_interactions2['daysSinceLastInteraction'] = (date_measure - df_interactions2['lastInteractionDate']).dt.days.astype(int)

# %% [markdown]
# Merge df contacts2 with df interactions2

# %%
merge = pd.merge(df_contacts2, df_interactions2, on=['company', 'companyId'], how='left')

# %% [markdown]
# Create the final merge on new df "merge" and offer2

# %%
merge_full = pd.merge(merge, df_offer2, on=['company', 'companyId'], how='left')

# %% [markdown]
# Create the second feature based on lastOfferDate

# %%
merge_full['daysSinceLastOfferClosed'] = (date_measure - merge_full['lastOfferDate']).dt.days.astype(int)

# %% [markdown]
# Create additional new feature to define the offerHitRate

# %%
merge_full['daysSinceLastOfferClosed'] = (date_measure - merge_full['lastOfferDate']).dt.days.astype(int)

# %% [markdown]
# Checking the dataset

# %%
merge_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   companyId                 2000 non-null   int64
#  1   company                   2000 non-null   object
#  2   size                      2000 non-null   object
#  3   industry                  2000 non-null   object
#  4   city                      2000 non-null   object
#  5   state                     2000 non-null   object
#  6   contacts                  2000 non-null   int64
#  7   roles                     2000 non-null   object
#  8   interactions              2000 non-null   int64
#  9   lastInteractionDate       2000 non-null   datetime64[ns]
#  10  interactionSubjects       2000 non-null   object
#  11  daysSinceLastInteraction  2000 non-null   int32
#  12  offers                    2000 non-null   int64
#  13  averageOfferValue         2000 non-null   float64
#  14  offerClosed               2000 non-null   int64
#  15  lastOfferDate             2000 non-null   datetime64[ns]
#  16  daysSinceLastOfferClosed  2000 non-null   int32
# dtypes: datetime64[ns](2), float64(1), int32(2), int64(5), object(7)
# memory usage: 250.1+ KB

# %% [markdown]
# Do additional checking based on a certain of criteria

# %%
check = merge[(merge['contacts'] == 0) & (merge['interactions'] > 0)]
check
# Out:
# Empty DataFrame
# Columns: [companyId, company, size, industry, city, state, contacts, roles, interactions, lastInteractionDate, interactionSubjects, daysSinceLastInteraction]
# Index: []

# %%
check2 = merge_full[(merge_full['contacts'] ==0) & (merge_full['offers'] > 0)]
check2
# Out:
# Empty DataFrame
# Columns: [companyId, company, size, industry, city, state, contacts, roles, interactions, lastInteractionDate, interactionSubjects, daysSinceLastInteraction, offers, averageOfferValue, offerClosed, lastOfferDate, daysSinceLastOfferClosed]
# Index: []

# %%
check3 = merge_full[(merge_full['contacts'] == 0)]
check3
# Out:
# Empty DataFrame
# Columns: [companyId, company, size, industry, city, state, contacts, roles, interactions, lastInteractionDate, interactionSubjects, daysSinceLastInteraction, offers, averageOfferValue, offerClosed, lastOfferDate, daysSinceLastOfferClosed]
# Index: []

# %% [markdown]
# Get more insights about the dataset

# %%
merge_full.describe()
# Out:
#           companyId     contacts  interactions            lastInteractionDate  \
# count   2000.000000  2000.000000    2000.00000                           2000
# mean    9940.728000     2.000000      16.00000  2024-08-23 02:21:07.200000256
# min       13.000000     1.000000       4.00000            2023-07-04 00:00:00
# 25%     4867.750000     1.000000      13.00000            2024-07-30 00:00:00
# 50%     9958.500000     2.000000      16.00000            2024-09-11 12:00:00
# 75%    14886.750000     3.000000      19.00000            2024-10-09 00:00:00
# max    19985.000000     7.000000      29.00000            2024-10-29 00:00:00
# std     5753.653107     0.995236       4.02394                            NaN
#
#        daysSinceLastInteraction       offers  averageOfferValue  offerClosed  \
# count               2000.000000  2000.000000        2000.000000  2000.000000
# mean                  99.902000    20.000000       10000.493480     8.992500
# min                   33.000000     7.000000        9348.400000     1.000000
# 25%                   53.000000    17.000000        9850.867500     7.000000
# 50%                   80.500000    20.000000       10003.880000     9.000000
# 75%                  124.000000    23.000000       10151.050000    11.000000
# max                  516.000000    36.000000       10871.680000    19.000000
# std                   66.294048     4.456673         223.555698     2.986453
#
#              lastOfferDate  daysSinceLastOfferClosed
# count                 2000               2000.000000
# mean   2024-09-02 11:49:12                 89.507500
# min    2023-06-04 00:00:00                 33.000000
# 25%    2024-08-12 00:00:00                 49.000000
# 50%    2024-09-18 12:00:00                 73.500000
# 75%    2024-10-13 00:00:00                111.000000
# max    2024-10-29 00:00:00                546.000000
# std                    NaN                 58.080983

# %% [markdown]
# Create a function for feature_target

# %%
def categorize_customer(i):
    if i <= 7:
        return 'C'
    elif 7 <= i <= 10:
        return 'B'
    else:
        return 'A'

merge_full['customerClassification'] = merge_full['offerClosed'].apply(categorize_customer)

# %% [markdown]
# Check the dataset

# %%
merge_full
# Out:
#       companyId                          company    size  \
# 0            13              Stephens-Washington   Large
# 1            16                        Moore Ltd   Large
# 2            23                      Payne Group   Large
# 3            31      Martinez, Benson and Bowman   Large
# 4            39                       Meyer-Gill  Medium
# ...         ...                              ...     ...
# 1995      19961                      Stanley Inc   Small
# 1996      19975                        Hayes PLC   Small
# 1997      19978           Parks, Moss and Howell   Large
# 1998      19980  Nixon, Zimmerman and Washington  Medium
# 1999      19985                        Rocha Ltd   Small
#
#                                 industry               city           state  \
# 0        Ridesharing & Mobility Services  New Yvonneborough        Delaware
# 1      Connected Car Solutions Providers          Brianstad       Tennessee
# 2        Automobile Manufacturers (OEMs)       North Sylvia           Texas
# 3                       Fleet Management          Ginamouth  North Carolina
# 4     Automotive R&D and Testing Centers         Loganville         Arizona
# ...                                  ...                ...             ...
# 1995                    Fleet Management           Donburgh         Indiana
# 1996   Connected Car Solutions Providers        Thomasmouth         Vermont
# 1997                    Fleet Management      Lake Johnview        Colorado
# 1998     Ridesharing & Mobility Services      New Jasonberg         Vermont
# 1999                    Fleet Management      West Samantha   West Virginia
#
#       contacts                                             roles  \
# 0            2                                Sales Manager, CEO
# 1            2                         CFO, Sales Representative
# 2            1                                     Sales Manager
# 3            2                                          CCO, CFO
# 4            4          CEO, Sales Representative, Sales Manager
# ...        ...                                               ...
# 1995         2                                Sales Manager, CFO
# 1996         4             Sales Manager, CEO, Technical Manager
# 1997         2                                     Sales Manager
# 1998         1                          Technical Representative
# 1999         4  Technical Manager, Technical Representative, CEO
#
#       interactions lastInteractionDate  \
# 0               20          2024-08-22
# 1               13          2024-08-04
# 2               13          2024-10-19
# 3               12          2024-05-26
# 4               16          2024-06-10
# ...            ...                 ...
# 1995            26          2024-08-08
# 1996            22          2024-09-10
# 1997            19          2024-10-18
# 1998            14          2024-09-23
# 1999            12          2024-08-14
#
#                                     interactionSubjects  \
# 0     Follow-up on proposal, Follow-up on order, Pro...
# 1     Follow-up on order, Discuss project details, P...
# 2     Contract negotiation, Product feedback, Produc...
# 3     Follow-up on order, Contract negotiation, Foll...
# 4     Follow-up on order, Discuss project details, C...
# ...                                                 ...
# 1995  Discuss project details, Follow-up on proposal...
# 1996  Product feedback, Customer inquiry, Contract n...
# 1997  Discuss project details, Customer inquiry, Pro...
# 1998  Product feedback, Discuss project details, Fol...
# 1999  Customer inquiry, Discuss project details, Con...
#
#       daysSinceLastInteraction  offers  averageOfferValue  offerClosed  \
# 0                          101      20           10169.80           10
# 1                          119      12            9903.13            7
# 2                           43      20           10208.89            9
# 3                          189      17            9955.58            8
# 4                          174      20            9847.54           12
# ...                        ...     ...                ...          ...
# 1995                       115      18            9980.28            6
# 1996                        82      12           10056.84            3
# 1997                        44      17           10185.14            5
# 1998                        69      26           10116.77            9
# 1999                       109      18           10063.92            8
#
#      lastOfferDate  daysSinceLastOfferClosed customerClassification
# 0       2024-10-14                        48                      B
# 1       2024-09-13                        79                      C
# 2       2024-09-06                        86                      B
# 3       2024-07-16                       138                      B
# 4       2024-10-26                        36                      A
# ...            ...                       ...                    ...
# 1995    2024-10-28                        34                      C
# 1996    2024-10-18                        44                      C
# 1997    2024-10-04                        58                      C
# 1998    2024-10-09                        53                      B
# 1999    2024-10-14                        48                      B
#
# [2000 rows x 18 columns]

# %% [markdown]
# Check the classification split for the feature target

# %%
customer_C = (merge_full['customerClassification'] == 'C').sum()
customer_B = (merge_full['customerClassification'] == 'B').sum()
customer_A = (merge_full['customerClassification'] == 'A').sum()
print(customer_C, customer_B, customer_A)
# Out:
# 653 764 583

# %% [markdown]
# Check the datatypes

# %%
merge_full.dtypes
# Out:
# companyId                            int64
# company                             object
# size                                object
# industry                            object
# city                                object
# state                               object
# contacts                             int64
# roles                               object
# interactions                         int64
# lastInteractionDate         datetime64[ns]
# interactionSubjects                 object
# daysSinceLastInteraction             int32
# offers                               int64
# averageOfferValue                  float64
# offerClosed                          int64
# lastOfferDate               datetime64[ns]
# daysSinceLastOfferClosed             int32
# customerClassification              object
# dtype: object

# %%
merge_full = merge_full.astype({'interactions' : 'int', 'offers' : 'int', 'offerClosed' : 'int', 'daysSinceLastInteraction' : 'int'})
merge_full.dtypes
# Out:
# companyId                            int64
# company                             object
# size                                object
# industry                            object
# city                                object
# state                               object
# contacts                             int64
# roles                               object
# interactions                         int32
# lastInteractionDate         datetime64[ns]
# interactionSubjects                 object
# daysSinceLastInteraction             int32
# offers                               int32
# averageOfferValue                  float64
# offerClosed                          int32
# lastOfferDate               datetime64[ns]
# daysSinceLastOfferClosed             int32
# customerClassification              object
# dtype: object

# %% [markdown]
# Check the dataset again

# %%
merge_full.info()
merge_full.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   companyId                 2000 non-null   int64
#  1   company                   2000 non-null   object
#  2   size                      2000 non-null   object
#  3   industry                  2000 non-null   object
#  4   city                      2000 non-null   object
#  5   state                     2000 non-null   object
#  6   contacts                  2000 non-null   int64
#  7   roles                     2000 non-null   object
#  8   interactions              2000 non-null   int32
#  9   lastInteractionDate       2000 non-null   datetime64[ns]
#  10  interactionSubjects       2000 non-null   object
#  11  daysSinceLastInteraction  2000 non-null   int32
#  12  offers                    2000 non-null   int32
#  13  averageOfferValue         2000 non-null   float64
#  14  offerClosed               2000 non-null   int32
#  15  lastOfferDate             2000 non-null   datetime64[ns]
#  16  daysSinceLastOfferClosed  2000 non-null   int32
#  17  customerClassification    2000 non-null   object
# dtypes: datetime64[ns](2), float64(1), int32(5), int64(2), object(8)
# memory usage: 242.3+ KB
#           companyId     contacts  interactions            lastInteractionDate  \
# count   2000.000000  2000.000000    2000.00000                           2000
# mean    9940.728000     2.000000      16.00000  2024-08-23 02:21:07.200000256
# min       13.000000     1.000000       4.00000            2023-07-04 00:00:00
# 25%     4867.750000     1.000000      13.00000            2024-07-30 00:00:00
# 50%     9958.500000     2.000000      16.00000            2024-09-11 12:00:00
# 75%    14886.750000     3.000000      19.00000            2024-10-09 00:00:00
# max    19985.000000     7.000000      29.00000            2024-10-29 00:00:00
# std     5753.653107     0.995236       4.02394                            NaN
#
#        daysSinceLastInteraction       offers  averageOfferValue  offerClosed  \
# count               2000.000000  2000.000000        2000.000000  2000.000000
# mean                  99.902000    20.000000       10000.493480     8.992500
# min                   33.000000     7.000000        9348.400000     1.000000
# 25%                   53.000000    17.000000        9850.867500     7.000000
# 50%                   80.500000    20.000000       10003.880000     9.000000
# 75%                  124.000000    23.000000       10151.050000    11.000000
# max                  516.000000    36.000000       10871.680000    19.000000
# std                   66.294048     4.456673         223.555698     2.986453
#
#              lastOfferDate  daysSinceLastOfferClosed
# count                 2000               2000.000000
# mean   2024-09-02 11:49:12                 89.507500
# min    2023-06-04 00:00:00                 33.000000
# 25%    2024-08-12 00:00:00                 49.000000
# 50%    2024-09-18 12:00:00                 73.500000
# 75%    2024-10-13 00:00:00                111.000000
# max    2024-10-29 00:00:00                546.000000
# std                    NaN                 58.080983

# %% [markdown]
# Drop redundant features

# %%
merge_full = merge_full.drop(columns=['companyId', 'offers', 'lastInteractionDate', 'lastOfferDate'])

# %% [markdown]
# Generate a CSV.file

# %%
merge_full.to_csv('sum_customer_data.csv', index=False)
